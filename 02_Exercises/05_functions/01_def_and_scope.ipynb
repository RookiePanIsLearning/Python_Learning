# %% [markdown]
# # 模組 4：函式定義與變數作用域
#
# 目標：撰寫帶有預設參數與 return 的函式。

# %%
def greet(name, prefix="Hi"):
    return f"{prefix}, {name}!"

print(greet("Pan"))
print(greet("Pan", prefix="Hello"))

# %%
x = "global"

def show_scope():
    x = "local"
    print("inside:", x)

show_scope()
print("outside:", x)
